# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Online Retail.csv")

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 486210    577716     20914  SET/5 RED RETROSPOT LID GLASS BOWLS      32.0
# 486211    577718     22423             REGENCY CAKESTAND 3 TIER      32.0
# 486212    577718     22178      VICTORIAN GLASS HANGING T-LIGHT     192.0
# 486213    577719     22684        FRENCH BLUE METAL DOOR SIGN 9      10.0
# 486214         5       NaN                                  NaN       NaN
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0       01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1       01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2       01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3       01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4       01-12-2010 08:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 486210  21-11-2011 12:18       2.55     15857.0  United Kingdom
# 486211  21-11-2011 12:19      10.95     16013.0  United Kingdom
# 486212  21-11-2011 12:19       0.90     16013.0  United Kingdom
# 486213  21-11-2011 12:20       1.25     16013.0  United Kingdom
# 486214               NaN        NaN         NaN             NaN
#
# [486215 rows x 8 columns]

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  486214.000000  486214.000000  367077.000000
# mean        9.686936       4.618929   15282.343587
# std       159.937337      96.901263    1712.157666
# min    -74215.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13933.000000
# 50%         3.000000       2.080000   15150.000000
# 75%        10.000000       4.130000   16779.000000
# max     74215.000000   38970.000000   18287.000000

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 486210    577716     20914  SET/5 RED RETROSPOT LID GLASS BOWLS      32.0
# 486211    577718     22423             REGENCY CAKESTAND 3 TIER      32.0
# 486212    577718     22178      VICTORIAN GLASS HANGING T-LIGHT     192.0
# 486213    577719     22684        FRENCH BLUE METAL DOOR SIGN 9      10.0
# 486214         5       NaN                                  NaN       NaN
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 486210  21-11-2011 12:18       2.55     15857.0  United Kingdom
# 486211  21-11-2011 12:19      10.95     16013.0  United Kingdom
# 486212  21-11-2011 12:19       0.90     16013.0  United Kingdom
# 486213  21-11-2011 12:20       1.25     16013.0  United Kingdom
# 486214               NaN        NaN         NaN             NaN

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES       2.0
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER       6.0
# 7    536366     22633               HAND WARMER UNION JACK       6.0
# 8    536366     22632            HAND WARMER RED POLKA DOT       6.0
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT      32.0
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 5  01-12-2010 08:26       7.65     17850.0  United Kingdom
# 6  01-12-2010 08:26       4.25     17850.0  United Kingdom
# 7  01-12-2010 08:28       1.85     17850.0  United Kingdom
# 8  01-12-2010 08:28       1.85     17850.0  United Kingdom
# 9  01-12-2010 08:34       1.69     13047.0  United Kingdom

# %%
df.shape
# Out:
# (486215, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486215 entries, 0 to 486214
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    486215 non-null  object
#  1   StockCode    486214 non-null  object
#  2   Description  484804 non-null  object
#  3   Quantity     486214 non-null  float64
#  4   InvoiceDate  486214 non-null  object
#  5   UnitPrice    486214 non-null  float64
#  6   CustomerID   367077 non-null  float64
#  7   Country      486214 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 29.7+ MB

# %%
df.UnitPrice
# Out:
# 0          2.55
# 1          3.39
# 2          2.75
# 3          3.39
# 4          3.39
#           ...
# 486210     2.55
# 486211    10.95
# 486212     0.90
# 486213     1.25
# 486214      NaN
# Name: UnitPrice, Length: 486215, dtype: float64

# %%
df.UnitPrice.hist()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.boxplot(df.UnitPrice)
# Out:
# <Axes: ylabel='UnitPrice'>

# %%
df = df[df.UnitPrice>=10000]

# %%
df.shape
# Out:
# (8, 8)

# %%
sns.boxplot(df.UnitPrice)
# Out:
# <Axes: ylabel='UnitPrice'>

# %%
df.Quantity.hist()
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     7
# Country        0
# dtype: int64

# %%
df.isin([0]).sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64
